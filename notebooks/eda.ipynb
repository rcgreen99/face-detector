# %%
import os
import sys
# import matplotlib.pyplot as plt
# import pandas as pd
# import numpy as np

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
from src.face_detection_dataset import FaceDetectionDataset

# %%
dataset = FaceDetectionDataset("../data/list_bbox_celeba.txt", "../data/imgs") # had to add ../ here to get the correct pat
len(dataset)
# Out:
# 202599

# %%
annotation = dataset[20] # 4 is example of bad crop
print(annotation)
annotation.open_image(show_bbox=True)
# Out:
# annotation ../data/imgs/000021.jpg (128, 27, 263, 214)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x280>

# %%
image = annotation.resize(annotation.open_image(), 224)
print("size:", image.size)
print("bbox: ", annotation.top_left_x, annotation.bottom_right_y, annotation.bottom_right_x, annotation.top_left_y)
annotation.draw_bbox(image)
# Out:
# size: (224, 224)
# bbox:  54.0 171 162.0 21
# <PIL.Image.Image image mode=RGB size=224x224>
